# %%
from ensure import ensure_annotations
from box.exceptions import BoxValueError
from box import ConfigBox

# %%
example={"key1": "value1", "key2": "value2", "key3": "value3"}

# %%
example['key1']
# Out:
# 'value1'

# %%
example.key1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 example.key1
#
# AttributeError: 'dict' object has no attribute 'key1'

# %%
example = ConfigBox({"key1": "value1", "key2": "value2", "key3": "value3"})

# %%
example.key1
# Out:
# 'value1'

# %%
#  Explaination ensure annotation

def get_product(x:int, y:int)->int:
    return x*y

# get_product(2,'3') # output 33


@ensure_annotations
def get_product(x: int, y: int) -> int:
    return x*y

get_product(2, '3') # stricterror
# Out:
# ---------------------------------------------------------------------------
# EnsureError                               Traceback (most recent call last)
# Cell In[20], line 13
#       9 @ensure_annotations
#      10 def get_product(x: int, y: int) -> int:
#      11     return x*y
# ---> 13 get_product(2, '3') # stricterror
#
# File c:\Users\hmadarw\Learnings\DataScience\KrishNaik\Project\datascienceproject\venv\Lib\site-packages\ensure\main.py:845, in WrappedFunctionReturn.__call__(self, *args, **kwargs)
#     840     if not isinstance(value, templ):
#     841         msg = (
#     842             "Argument {arg} of type {valt} to {f} "
#     843             "does not match annotation type {t}"
#     844         )
# --> 845         raise EnsureError(msg.format(
#     846             arg=arg, f=self.f, t=templ, valt=type(value)
#     847         ))
#     849 return_val = self.f(*args, **kwargs)
#     850 if not isinstance(return_val, self.return_templ):
#
# EnsureError: Argument y of type <class 'str'> to <function get_product at 0x000001DF9F3F8E00> does not match annotation type <class 'int'>
